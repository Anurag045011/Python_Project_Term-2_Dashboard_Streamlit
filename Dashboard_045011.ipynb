# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.6 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.201.139.15

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.185.155.94:8501
#
# npx: installed 22 in 5.308s
# your url is: https://few-vans-double.loca.lt

# %% [markdown]
# I have created a dashboard to visualize Phonepe pulse data using Streamlit and Plotly in Python
#
#
# THE MAIN COMPONENTS OF DASHBOARD ARE
#
# 1 GEO-VISUALIZATION
#
# 2 TRANSACTIONS ANALYSIS
#
# 3 USERS ANALYSIS
#
# 4 TOP STATES DATA
#
#
# **1 Geo-Visualization:**
# The India map shows the Total Transactions of PhonePe in both state wide and District wide.It comes with zoom option and on hover displays the content related to that particular state or district.The main functions I have used to create this map are (User can give year and quarter input to show how the data changed over time)
#
# 1 Plotlys scatter_geo for plotting districts along with the conent
#
# 2 Plotlys coropleth for drawing the states in India map
#
# **2 Transactions Analysis:**
#  The Transactions data mainly contains the total Transactions count and total amount in each state and district, I have used different graphs available in plotly to represent this data
#
# **1 State-wise study**
#
# The above bar graph shows the increasing order of PhonePe Transactions according to the states of India,
# Here we can observe the top states with the highest Transaction by looking at graph
#
# **2 District-wise study**
#
# User can observe how transactions are happening in districts of a selected state.We can observe the
# leading distric in a state
#
# **3 Year-wise study**
#
# We can observe the states with total transactions in particular mode in the selected year
#
# **4 Overall Analysis**
#
# To show how the transactions drastically increased with time
#
# **3 User Data Analysis:**
#
# The Users data mainly contains the Registered Users count and App openings via different mobile brands in each state and district,I have used different graphs available in plotly to represent this data
#
# **1 State-wise study**
#
# User can observe how the App Openings are growing and how Registered users are growing in a state
#
# **2 District-wise study**
# User can observe how App Openings are happening in districts of a selected state
#
# **3 Year-wise study **
#
# User can observe the top leading brands in a particular state in given year
#
# **4 Overall Analysis**
#
# We can see that the Registered Users and App openings are increasing year by year
#
#
# **4 Top States Data:**
#
# 1 States with top Registered users
# 2 States with top Total Amount Transacted
# 3 States with highest Trabsactions count
# 4 States with top app openings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives**
#
# Objective 1: Statewide Transaction Overview
# Provide a visual representation of total transactions in each state.
# Use the darkness of state colors to indicate transaction intensity.
#
# Objective 2: Districtwise Transaction Insight
# Display district-wise transactions using circles, with size proportional to transaction volume.
# Utilize hover data to present details such as total transactions and total amount for each district.
#
# **2. Data Overview**
#
# Data Source:
# Utilizing PhonePe Pulse Data for the given year and quarter.
#
# **3. Visualizations**
#
# Statewide Choropleth Map:
#
# Colors represent the total transactions in each state, with darker shades indicating higher transaction volumes.
# Districtwise Bubble Map:
#
# Circles depict district-wise transactions, with larger circles corresponding to higher transaction volumes.
# Hover data displays details like total transactions and total amount for each district.
#
# **4. Observations and Insights**
#
# Highest Transaction States:
# Identify states with the darkest colors on the choropleth map to pinpoint those with the highest transaction volumes.
#
# Districtwide Transaction Patterns:
# Observe bubble sizes on the districtwise map to understand variations in transaction volumes across districts.
#
# Hover Data Insights:
# Utilize hover data to extract specific details about individual districts, providing a deeper understanding of transaction patterns.
#
# **5. Managerial Implications**
#
# Strategic Focus:
# Allocate resources and marketing efforts to states with the highest transaction volumes for optimized results.
#
# District-Level Initiatives:
# Implement targeted initiatives in districts with significant transaction volumes to enhance user engagement.
#
# Performance Evaluation:
# Evaluate the success of promotional activities and marketing campaigns by comparing transaction data across districts.
#
# **Conclusion:**
#
# This analysis provides a comprehensive visual overview of PhonePe Pulse Data, allowing stakeholders to grasp transaction patterns at both statewide and districtwise levels. The combination of choropleth and bubble maps, along with hover data, offers a rich and informative representation of transaction trends.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives**
#
# Objective 1: Statewise Transaction Overview
# Visualize total transactions in each state using a dynamic bar graph.
# Enable users to choose different years (2018-2022) and quarters (1-4) with dropdown buttons.
#
# **2. Data Overview**
#
# Data Source:
# Utilizing PhonePe Pulse Data for the specified years and quarters.
# Key Data Points:
# State
# Year
# Quarter
# Total Transactions
# Total Amount
#
# **3. Visualizations**
#
# Bar Graph with Dropdowns:
# Display a dynamic bar graph with states on the x-axis and total transactions on the y-axis.
# Include dropdown menus for users to select different years and quarters.
#
# **4. Observations and Insights**
#
# Dynamic Selection:
# Users can interactively choose the year and quarter of interest, providing a tailored view of transaction patterns.
#
# Comparative Analysis:
# Visualize variations in total transactions across states for different quarters and years.
#
# **5. Managerial Implications**
#
# Strategic Resource Allocation:
# Enable stakeholders to allocate resources effectively based on dynamic insights into transaction trends.
#
# Decision Support:
# Provide decision-makers with a tool to assess the impact of marketing strategies and user engagement initiatives.
#
# **6. Conclusion**
#
# The dynamic bar graph with dropdowns offers a user-friendly and insightful representation of PhonePe Pulse Data for statewise transactions.
# Users can explore and compare transaction trends across different years and quarters, facilitating informed decision-making.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives**
#
# Objective 1: Statewise Transaction Analysis
# Conduct a comprehensive analysis of transactions, focusing on a user-selected state.
# Utilize a bar graph to visually represent total transactions across all years and quarters for the chosen state.
#
# Objective 2: Payment Mode Patterns
# Examine the nuanced patterns of payment modes within the selected state.
# Identify trends and variations in the usage of different payment modes over various years and quarters.
#
# **2. Data Overview**
#
# Data Source:
# Transaction data segregated by state, year, quarter, and payment modes.
# Key Data Points:
# State (user-selected)
# Year
# Quarter
# Payment Modes
# Total Transactions
#
# **3. Visualization**
#
# Bar Graph:
# A user-friendly bar graph displaying transaction trends in the selected state.
# X-axis represents all years with respective quarters, and Y-axis represents total transactions.
# Users can dynamically choose different states to update the analysis.
#
# **4. Observations and Insights**
#
# Transaction Patterns:
# Observe the transaction patterns to discern any seasonal or yearly variations within the selected state.
#
# Mode Trends:
# Identify specific payment modes that show consistent growth, decline, or fluctuations over time.
# Examine any notable spikes or drops in the usage of certain modes.
#
# Comparative Analysis:
# Conduct a comparative analysis between different payment modes to understand the overall landscape.
#
# **5. Managerial Implications**
#
# Strategic Decision-Making:
# Provide decision-makers with actionable insights to make strategic decisions based on observed transaction trends.
#
# Marketing Strategy Adjustment:
# Adjust marketing strategies and promotional activities based on the prevalent payment mode preferences within the selected state.
#
# Customer Engagement:
# Enhance customer engagement by aligning services and incentives with the popular payment modes.
#
# **6. Conclusion**
#
# The statewise transaction analysis, represented through the bar graph, offers a detailed and dynamic view of transaction patterns.
# Insights into payment mode trends empower decision-makers to make informed adjustments to strategies for optimal outcomes.
#
#
# **User Interaction:**
#
# Consider incorporating interactive features allowing users to select specific payment modes for a more focused analysis.
#
# **Long-Term Trend Analysis:**
#
# Extend the analysis to explore long-term trends and their impact on payment mode preferences within the selected state.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives**
#
# Objective: Districtwise Transaction Analysis
# Conduct a detailed analysis of transactions at the district level within a user-selected state.
# Utilize a bar graph to visually represent total transactions across districts for a chosen year and state.
#
# **2. Data Overview**
#
# Data Source:
# Transaction data categorized by state, year, quarter, and districts.
#
# Key Data Points:
#
# State (user-selected)
#
# Year (user-selected)
#
# Districts
#
# Total Transactions
#
# **3. Visualization**
#
# Bar Graph:
# Display a bar graph where the X-axis represents districts of the selected state, and the Y-axis represents total transactions.
# Users can dynamically select different years and states to update the analysis.
#
# **4. Observations and Insights**
#
# Transaction Distribution:
# Observe the distribution of transactions across districts in the selected state for a specific year.
# Identify leading districts with higher transaction volumes.
#
# Comparative Analysis:
# Conduct a comparative analysis to understand variations in transaction volumes among different districts.
#
# **5. Managerial Implications**
#
# Resource Allocation:
# Provide insights for resource allocation, allowing stakeholders to focus efforts and resources on districts with higher transaction volumes.
#
# District-Level Initiatives:
# Implement targeted initiatives at the district level to enhance user engagement and transaction activity.
#
# Performance Assessment:
# Evaluate the success of promotional activities and marketing campaigns based on district-wise transaction data.
#
# **6. Conclusion**
#
# The districtwise transaction analysis, represented through the bar graph, offers a localized view of transaction patterns within a selected state.
# Insights into transaction distribution across districts empower decision-makers to tailor strategies for optimized results.
#
# **Next Steps:**
#
# **User Interaction:**
# Enhance user interaction by allowing users to explore transaction details for specific districts within the selected state.
#
# **Trend Analysis:**
# Extend the analysis to explore transaction trends over multiple years, providing a longitudinal perspective.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives**
#
# Objective: Yearwise Transaction Analysis by Mode
# Conduct a detailed analysis of transactions for a specific mode of payment across all states within a selected year.
# Utilize a bar graph to visually represent total transactions for the chosen mode in increasing order of states.
#
# **2. Data Overview**
#
# Data Source:
# Transaction data categorized by state, year, quarter, and modes of payment (e.g., Recharge and bill payment, Peer to peer payment, Merchant payment, Financial service, Others).
#
# Key Data Points:
#
# Year (user-selected)
#
# Modes of Payment
#
# States
#
# Total Transactions
#
# **3. Visualization**
#
# Bar Graph:
# Display a bar graph where the X-axis represents states in increasing order of total transactions, and the Y-axis represents total transactions for the selected mode of payment.
# Users can dynamically select different years and modes to update the analysis.
#
# **4. Observations and Insights**
#
# Leading State:
# Identify the leading state with the highest transactions for the selected mode of payment within the chosen year.
# Observe regional performance trends.
#
# Regional Performance:
# Assess the regional performance of PhonePe in terms of total transactions, providing insights for targeted offers and promotions.
#
# **5. Managerial Implications**
#
# Targeted Offers:
# Use insights to provide targeted offers to regions with high transaction volumes, enhancing user engagement.
#
# Regional Marketing Strategies:
# Tailor marketing strategies based on the observed performance of PhonePe in different states.
#
# Performance-Based Incentives:
# Implement performance-based incentives for users and merchants in regions contributing significantly to the total transactions.
#
# **6. Conclusion**
#
# The yearwise transaction analysis by mode, represented through the bar graph, offers insights into the regional performance of PhonePe.
# Strategic decisions can be made based on regional transaction patterns, enabling targeted promotional activities.
#
# **Next Steps:**
#
# **User Interaction:**
#
# Enhance user interaction by allowing users to explore transaction details for specific modes within different states.
#
# **Mode-specific Trends:**
#
# Explore mode-specific trends over multiple years to understand the evolving dynamics of payment preferences.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives:**
#
# Objective: Comprehensive Understanding of Transaction Trends
#
# Gain insights into the overall transaction patterns of PhonePe over the years.
# Identify key trends, growth phases, and the impact of each year on total transactions.
#
# **2. Data Overview:**
#
# Data Source:
#
# Transaction data spanning from 2018 to 2022, segmented by years, quarters, and transaction details.
# Key Data Points:
#
# Year
#
# Quarter
#
# Total Transactions
#
# **3. Visualization:**
#
# **Visualization Technique: Pie Chart**
#
# Utilize a pie chart to illustrate the contribution of each year to the total transactions.
# Each slice of the pie represents a specific year, providing a clear breakdown of the overall composition.
#
# **Observations:**
#
# **Exponential Growth in Online Transactions:**
#
# A noticeable trend indicates a significant increase in online transactions over time.
# The initial years of 2018 and 2019 show relatively lower transaction numbers.
#
# **Rapid Increase in Usage:**
#
# A substantial surge in online payments via PhonePe is evident as the years progress.
# The data underscores a dynamic shift towards digital transactions in the given period.
#
# **Dominance of 2022:**
#
# The year 2022 emerges as a pivotal year, contributing to more than 50% of total PhonePe transactions in India.
# This highlights a substantial leap in user adoption and usage of the platform.
#
# **Key Takeaways:**
#
# **Market Penetration:**
#
# PhonePe has successfully penetrated the market, with a notable increase in user transactions.
# The observed growth suggests a positive response from users towards online payment solutions.
#
# **User Adoption Curve:**
#
# The initial years may indicate a phase of building trust and awareness among users.
# The subsequent surge in transactions suggests a successful transition to mainstream adoption.
#
# **Strategic Insights for PhonePe:**
#
# The data provides strategic insights for PhonePe to focus on sustaining and capitalizing on the surge in transactions.
# Tailoring marketing strategies to leverage the growing trend in digital transactions could further enhance the platform's market presence.
#
# **Conclusion:**
#
# The overall analysis of PhonePe transactions highlights a remarkable trajectory of growth, with a substantial increase in online transactions. The platform has experienced significant user adoption, especially in the pivotal year of 2022. Understanding these trends allows stakeholders to make informed decisions and devise strategies that align with the evolving landscape of digital payments in India.
#
# **Next Steps:**
#
# **User Behavior Analysis:**
#
# Dive deeper into user behavior patterns to understand preferences and factors driving increased usage.
#
# **Market Expansion Strategies:**
#
# Explore opportunities for market expansion and user outreach to capitalize on the positive momentum.
#
# **Collaborations and Offerings:**
#
# Evaluate potential collaborations and innovative offerings to further enhance user engagement and satisfaction.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives**
#
# Objective 1: Statewise User Analysis
# Conduct a thorough analysis of user data, emphasizing a user-selected state.
# Utilize a bar graph to visually represent the percentage of registered users and app openings over time.
#
# Objective 2: User Growth Observation
# Examine how app openings and registered user numbers have evolved in the selected state.
# Provide insights into the growth trends and patterns of the user base over time.
#
# **2. Data Overview**
#
# Data Source:
#
# User data categorized by state, time (years), registered users, and app openings.
#
# Key Data Points:
#
# State (user-selected)
#
# Time (years)
#
# Registered Users
#
# App Openings
#
# **3. Visualization**
#
# **Bar Graph:**
#
# A bar graph presenting the percentage of registered users and app openings over time for the chosen state.
# X-axis displays time (years), while the Y-axis shows the percentage of registered users and app openings.
# Users can dynamically select different states to update the analysis.
#
# **4. Observations and Insights**
#
# User Growth Trends:
# Observe the growth trends of both registered users and app openings within the selected state.
# Identify periods of significant growth or potential challenges.
#
# Comparative Analysis:
# Conduct a comparative analysis between registered users and app openings to understand their correlation.
#
# Impact of Time:
# Assess how user behavior and app engagement have changed over different time periods.
#
# **5. Managerial Implications**
#
# Strategic Decision-Making:
# Empower decision-makers with insights to make strategic decisions based on observed user growth patterns.
#
# Marketing Strategy Alignment:
# Align marketing strategies and promotional activities with the observed user growth trends.
#
# User Engagement Enhancement:
# Implement initiatives to enhance user engagement based on the changing dynamics of registered users and app openings.
#
# **6. Conclusion**
#
# The statewise user data analysis, represented through the bar graph, offers a detailed view of user growth trends.
# Insights into the percentage of registered users and app openings empower decision-makers to tailor strategies for optimal user engagement.
#
# **Next Steps:**
#
# **User Interaction:**
#
# Consider incorporating interactive features allowing users to select specific time periods for a more granular analysis.
#
# **Retention Analysis:**
#
# Extend the analysis to explore user retention rates and factors influencing user engagement over time.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives:**
#
# Objective: In-Depth Analysis of App Openings Across Districts
#
# Conduct a detailed analysis of App Openings, focusing on different districts within a selected state.
#
# Utilize a bar graph to visually represent the distribution of App Openings across districts for a chosen year, state, and quarter.
#
# **2. Data Overview:**
#
# Data Source:
#
# User data segmented by year, state, quarter, and districts.
#
# Key Data Points:
#
# Year (user-selected)
#
# State (user-selected)
#
# Quarter (user-selected)
#
# Districts
#
# App Openings
#
# **3. Visualization:**
#
# **Visualization Technique: Bar Graph**
#
# Display a bar graph where the X-axis represents districts of the selected state, and the Y-axis represents App Openings.
#
# Users can dynamically select different years, states, and quarters to update the analysis.
#
# **4. Observations and Insights:**
#
# Leading District for App Openings:
#
# The bar graph highlights the distribution of App Openings across different districts in the selected state.
# Identify the leading district with the highest number of App Openings, providing insights into user engagement.
#
# **Comparative Analysis:**
#
# Conduct a comparative analysis to understand variations in App Openings among different districts.
# Observe any notable trends or patterns that may influence strategic decisions.
#
# **5. Managerial Implications:**
#
# User Engagement Strategies:
#
# Leverage insights from leading districts to formulate targeted user engagement strategies.
# Tailor marketing efforts and promotions based on the observed distribution of App Openings.
# District-Specific Initiatives:
#
# Implement district-specific initiatives to enhance user experiences and increase App Openings.
# Collaborate with local partners or influencers in leading districts to boost engagement.
#
# **6. Conclusion:**
#
# The district-level analysis of App Openings provides valuable insights into the geographic distribution of user engagement. Identifying the leading district in terms of App Openings allows stakeholders to develop targeted strategies for improved user experiences and increased platform usage.
#
# **Next Steps:**
#
# **User Behavior Analysis:**
#
# Conduct a deeper analysis of user behavior within leading districts to understand preferences and usage patterns.
#
# **Localized Campaigns:**
#
# Design localized marketing campaigns or promotions based on district-specific findings.
#
# **Feedback Mechanisms:**
#
# Establish feedback mechanisms to gather insights directly from users in leading districts, facilitating continuous improvement.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives:**
#
# Objective: Understand the Distribution of Registered Users Across Device Brands
#
# Utilize a donut chart to visually represent the percentage share of registered users based on device brands.
#
# Analyze brand share in different states and years to identify trends and opportunities.
#
# **2. Data Overview:**
#
# Data Source:
#
# User data segmented by state and year, with information on registered users and their corresponding device brands.
#
# **3. Visualization:**
#
# **Visualization Technique: Donut Chart**
#
# Create a donut chart where each segment represents a device brand.
# The size of each segment corresponds to the percentage of registered users associated with that brand.
#
# **4. Important Observations:**
#
# Top Leading Brands:
#
# Identify the top brands with a significant percentage share of registered users in a particular state.
#
# Understand the brands that dominate the market and have a large user base.
#
# Brands with Less Users:
#
# Observe brands with a smaller share of registered users, indicating potential growth areas.
# Identify brands that may benefit from targeted marketing efforts.
#
# Brands with High Users:
#
# Recognize brands that attract a high percentage of registered users, representing strong market presence.
#
# Explore potential collaborations or partnerships with popular brands.
#
# **App Download Recommendations:**
#
# Provide app download recommendations based on brand share trends.
# Encourage users to download the app associated with leading brands for an optimized experience.
#
# **5. Managerial Implications:**
#
# Strategic Partnerships:
#
# Consider forming strategic partnerships with leading device brands to enhance market presence.
# Collaborate on promotional activities to attract more users.
#
# Targeted Marketing:
#
# Focus marketing efforts on brands with less user share to encourage growth.
# Tailor promotions and incentives to attract users from specific brands.
#
# User Experience Optimization:
#
# Work closely with brands with high user share to optimize the user experience for their devices.
# Ensure seamless integration and performance on popular device brands.
#
# **6. Conclusion:**
#
# The donut chart depicting brand share provides a visual representation of the distribution of registered users across different device brands. This analysis equips stakeholders with insights to make informed decisions regarding strategic partnerships, targeted marketing, and user experience optimization.
#
# **Next Steps:**
#
# **User Feedback Analysis:**
#
# Analyze user feedback associated with different device brands to identify areas for improvement.
#
# **Device-Specific Features:**
#
# Explore the integration of device-specific features to enhance the user experience on popular brands.
#
# **Continuous Monitoring:**
#
# Continuously monitor brand share trends to adapt strategies based on evolving user preferences.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objectives:**
#
# Objective: Comprehensive Analysis of User Data Over the Years
#
# Conduct an overall analysis of user data, focusing on the growth of Registered Users and App Openings.
#
# Utilize a donut chart to visually represent the distribution and growth of both Registered Users and App Openings across different years.
#
# **2. Data Overview:**
#
# Data Source:
#
# User data segmented by year, providing insights into the number of Registered Users and App Openings.
#
# Key Data Points:
#
# Year
#
# Registered Users
#
# App Openings
#
# **3. Visualization:**
#
# **Visualization Technique: Donut Chart**
#
# Create a donut chart where each ring represents a specific year.
# Segments within each ring correspond to the proportion of Registered Users and App Openings.
#
# **4. Observations and Insights:**
#
# Yearly Growth Trend:
#
# The donut chart illustrates the growth trends of both Registered Users and App Openings year by year.
# Observe the expanding segments to identify periods of substantial growth.
#
# **Comparative Analysis:**
#
# Conduct a comparative analysis between Registered Users and App Openings to understand their proportional growth rates.
# Identify any disparities or correlations that may influence strategic decisions.
#
# **5. Managerial Implications:**
#
# Resource Allocation:
#
# Allocate resources based on the observed growth patterns to support the increasing demand for both Registered Users and App Openings.
# Marketing Strategies:
#
# Tailor marketing strategies to sustain and further boost the growth of both user categories.
# Identify effective channels for promoting both user registration and app usage.
#
# **6. Conclusion:**
#
# The donut chart depicting overall user data analysis provides a visual representation of the growing trends in Registered Users and App Openings. The observed increase year by year indicates a positive trajectory for the platform. This analysis equips stakeholders with insights to make informed decisions regarding resource allocation and marketing strategies.
#
# **Next Steps:**
#
# **User Engagement Strategies:**
#
# Formulate user engagement strategies based on the observed growth patterns, enhancing overall user experiences.
#
# **Feedback Mechanisms:**
#
# Establish feedback mechanisms to understand user preferences and areas for improvement.
#
# **Promotional Campaigns:**
#
# Design promotional campaigns that target both increasing user registrations and encouraging app usage.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Objective:**
#
# Objective: Identify and Analyze Key Metrics for the Top 3 States in 2022
#
# Focus on the top three states with the highest metrics: Registered Users, App Openings, Total Transactions, and Total Amount.
# Provide insights into the performance and trends of these states.
#
# **2. Data Overview:**
#
# Top 3 States:
#
# Maharashtra
# Uttar Pradesh
# Karnataka
#
# **3. Analysis:**
#
# a) Registered Users:
#
# 1. Maharashtra: 48,227,630 Registered Users
# 2. Uttar Pradesh: 38,999,692 Registered Users
# 3. Karnataka: 31,200,349 Registered Users
# b) App Openings:
#
# 1. Rajasthan: 2,570,606,469 App Openings
# 2. Maharashtra: 2,157,769,514 App Openings
# 3. Karnataka: 1,727,054,045 App Openings
#
# c) Total Transactions:
#
# 1. Maharashtra: 1,169,506,438 Total Transactions
# 2. Karnataka: 1,057,855,407 Total Transactions
# 3. Telangana: 886,453,385 Total Transactions
#
# d) Total Amount:
#
# 1. Maharashtra: $1,681,399,273,981.13
#
# 2. Telangana: $1,670,638,169,828.97
#
# 3. Karnataka: $1,566,649,488,305.88
#
# **4. Insights:**
#
# User Base Strength:
#
# Maharashtra leads in Registered Users, indicating a robust user base.
# Karnataka and Uttar Pradesh also boast significant user numbers.
# App Engagement:
#
# Rajasthan has the highest App Openings, suggesting strong engagement in this state.
# Maharashtra and Karnataka follow closely in app usage.
# Transaction Volumes:
#
# Maharashtra dominates in Total Transactions, indicating a high volume of transactions.
# Karnataka and Telangana also exhibit substantial transaction numbers.
# Monetary Transactions:
#
# Maharashtra, Telangana, and Karnataka lead in Total Amount, reflecting the highest monetary transactions.
#
# **5. Managerial Implications:**
#
# Strategic Focus:
#
# Allocate resources strategically to cater to the high user engagement in Maharashtra, Rajasthan, and Karnataka.
# Marketing Strategies:
#
# Tailor marketing strategies to enhance user acquisition and app engagement in Uttar Pradesh and Telangana.
#
# Transaction Optimization:
#
# Focus on optimizing transaction experiences in Karnataka, Telangana, and Maharashtra, where high transaction volumes are observed.
#
# **6. Conclusion:**
#
# The analysis of the top three states in 2022 provides valuable insights into user behavior, app engagement, and transaction dynamics. Stakeholders can leverage this information to formulate targeted strategies and enhance overall performance in these key regions.
#
# **Next Steps:**
#
# **User Behavior Analysis:**
#
# Conduct a detailed study of user behavior in these states to understand preferences and tailor experiences accordingly.
#
# **Localized Campaigns:**
#
# Design localized marketing campaigns to further boost user registrations and app engagements in specific states.
#
# **Feedback Mechanisms:**
#
# Establish feedback mechanisms to gather insights directly from users in these states, facilitating continuous improvement.

# %% [markdown]
# **Sources-**
#
# Streamlit hosting-
# https://youtu.be/ZZsyxIWdCko?si=lIuUVnh3yCjeVynk
#
# Github link for codes and dataset-https://github.com/tulasinnd
